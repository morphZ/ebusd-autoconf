# %%
import pandas as pd

from autoconf.loader import build_message_data, load_config_tcp

# %%
config = load_config_tcp(host="pip.kirch.xyz")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 config = load_config_tcp(host="pip.kirch.xyz")
#
# File ~/src/ebusd-autoconf/autoconf/loader.py:35, in load_config_tcp(host, port)
#      34 def load_config_tcp(host: str = HOST, port: int = PORT) -> pd.DataFrame:
# ---> 35     config = send_ebusd_tcp("find -f\n", host=host, port=port)
#      36     num_cols = max([len(line.split(",")) for line in config.split("\n")])
#      37     col_names = [f"{i}" for i in range(0, num_cols)]
#
# File ~/src/ebusd-autoconf/autoconf/loader.py:21, in send_ebusd_tcp(command, host, port)
#      19 def send_ebusd_tcp(command: str, host: str = HOST, port: int = PORT) -> str:
#      20     with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
# ---> 21         s.connect((HOST, PORT))
#      22         s.sendall(command.encode())
#      24         buffer: bytes = b""
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %%
messages = config.apply(build_message_data, axis="columns").to_list()
df_m = pd.DataFrame.from_records(
    messages,
)

df_m
# Out:
#     type    circuit        name            comment  QQ   ZZ  PBSB          ID  \
# 0      u  broadcast    datetime      Datum/Uhrzeit NaN   fe  0700         NaN
# 1      u  broadcast       error    Fehlernachricht NaN   fe  fe01         NaN
# 2      u  broadcast   hwcStatus  Status Warmwasser NaN   fe  b505          27
# 3      u  broadcast          id     Identifikation NaN   fe  0704         NaN
# 4      r  broadcast          id     Identifikation NaN  NaN  0704         NaN
# ..   ...        ...         ...                ...  ..  ...   ...         ...
# 534    r      vwzio  xUnknown69                NaN NaN   76  b514  056903ffff
# 535    r      vwzio  xUnknown6A                NaN NaN   76  b514  056a03ffff
# 536    r      vwzio  xUnknown7B                NaN NaN   76  b514  057b03ffff
# 537    r      vwzio  xUnknown80                NaN NaN   76  b514  058003ffff
# 538   r5      vwzio  YieldTotal                NaN NaN   76  b516        1801
#
#      num_fields                                             fields
# 0             3            name ms datatypes_templates  divider...
# 1             1      name ms datatypes_templates  divider_value...
# 2             3      name ms datatypes_templates divider_values...
# 3             4             name ms datatypes_templates  \
# 0  m...
# 4             4             name ms datatypes_templates  \
# 0  m...
# ..          ...                                                ...
# 534           2     name ms datatypes_templates  divider_values...
# 535           2     name ms datatypes_templates  divider_values...
# 536           2     name ms datatypes_templates  divider_values...
# 537           2     name ms datatypes_templates  divider_values...
# 538           2       name ms datatypes_templates  divider_valu...
#
# [539 rows x 10 columns]
